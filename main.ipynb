# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport src.utils.plot
# %aimport src.utils
# %aimport src.feats

import src.utils as utils
import src.feats as feats

# %%
import run as main

# %%
variables = main.load_data(debug=True)
for name in variables:
    locals()[name] = variables[name]
del variables
# Out:
# Memory usage of dataframe is 286.23 MB
# Memory usage after optimization is: 92.38 MB
# Decreased by 67.7%
# Memory usage of dataframe is 45.00 MB
# Memory usage after optimization is: 14.60 MB
# Decreased by 67.6%
# Memory usage of dataframe is 471.48 MB
# Memory usage after optimization is: 309.01 MB
# Decreased by 34.5%
# Memory usage of dataframe is 222.62 MB
# Memory usage after optimization is: 112.95 MB
# Decreased by 49.3%
# Memory usage of dataframe is 610.43 MB
# Memory usage after optimization is: 238.45 MB
# Decreased by 60.9%
# Memory usage of dataframe is 673.88 MB
# Memory usage after optimization is: 289.33 MB
# Decreased by 57.1%
# Memory usage of dataframe is 830.41 MB
# Memory usage after optimization is: 311.40 MB
# Decreased by 62.5%

# %%
prev = utils.read_csv('./input/previous_application.csv')

# %%
    name_contract_cnt = (prev[['SK_ID_CURR', 'SK_ID_PREV', 'NAME_CONTRACT_STATUS']]
        .groupby(['SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
        .count()
        .unstack()
        .fillna(0)
        )

# %%
name_contract_cnt.columns = name_contract_cnt.columns.get_level_values(1)

# %%
name_contract_cnt
# Out:
# NAME_CONTRACT_STATUS  Approved  Canceled  Refused  Unused offer
# SK_ID_CURR
# 100001                     1.0       0.0      0.0           0.0
# 100002                     1.0       0.0      0.0           0.0
# 100003                     3.0       0.0      0.0           0.0
# 100004                     1.0       0.0      0.0           0.0
# 100005                     1.0       1.0      0.0           0.0
# 100006                     5.0       3.0      1.0           0.0
# 100007                     6.0       0.0      0.0           0.0
# 100008                     4.0       1.0      0.0           0.0
# 100009                     7.0       0.0      0.0           0.0
# 100010                     1.0       0.0      0.0           0.0
# 100011                     3.0       0.0      1.0           0.0
# 100012                     3.0       1.0      0.0           0.0
# 100013                     3.0       1.0      0.0           0.0
# ...

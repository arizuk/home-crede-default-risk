# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,5))
df46 = pd.read_csv('./experiments/046-lgbm-0.786859.csv')
df56 = pd.read_csv('./experiments/056-lgbm-0.786867.csv')
# sns.distplot(df46.TARGET)
sns.distplot(df56.TARGET)
# Out:
# /home/arizuka/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df57 = pd.read_csv('./experiments/057-lgbm-0.791295.csv')
sns.distplot(df57.TARGET)
# Out:
# /home/arizuka/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(15, 20))
imps = pd.read_csv('./experiments/057-features.csv')
sns.barplot(x='importance', y='features', data=imps.head(50))
# imps.head(50).plot.barh(x='features', y='importance', figsize=(20, 20), sort_columns='importance')

# %%
imps[imps.features.str.match('prev_')]
# Out:
#                                               features  importance
# 21                               prev_SELLERPLACE_AREA         978
# 22                                    prev_CNT_PAYMENT         969
# 25                   prev_X_AMT_APPLICATION_DIFF_RATIO         909
# 26                                    prev_AMT_ANNUITY         894
# 37                               prev_AMT_DOWN_PAYMENT         742
# 42                                        prev_Refused         638
# 45                                prev_AMT_GOODS_PRICE         616
# 46                                 prev_DAYS_FIRST_DUE         614
# 48                              prev_RATE_DOWN_PAYMENT         587
# 53                                  prev_DAYS_DECISION         533
# 54                                     prev_AMT_CREDIT         520
# 56                      prev_DAYS_LAST_DUE_1ST_VERSION         506
# 58                               prev_DAYS_TERMINATION         481
# ...
